# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('train_IA_-_train.csv')

# %%
test_data = pd.read_csv('test_IA_-_test.csv')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5800 entries, 0 to 5799
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Interview Id        5800 non-null   float64
#  1   Candidate Id        5800 non-null   float64
#  2   Interviewer Id      5800 non-null   int64
#  3   Profile             5800 non-null   object
#  4   S.L.R.C             5800 non-null   float64
#  5   S.L.R.I             5800 non-null   float64
#  6   A.T.T               5800 non-null   int64
#  7   L.M.I               5800 non-null   int64
#  8   L.M.C               5800 non-null   int64
#  9   S.R                 5800 non-null   int64
#  10  L.J.T.C             5800 non-null   int64
#  11  L.J.T.I             5800 non-null   int64
#  12  N.I.C               5800 non-null   int64
#  13  N.I.I               5800 non-null   int64
#  14  S.P.I               5800 non-null   int64
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Interview Id        1200 non-null   int64
#  1   Candidate Id        1200 non-null   float64
#  2   Interviewer Id      1200 non-null   int64
#  3   Profile             1200 non-null   object
#  4   S.L.R.C             1200 non-null   float64
#  5   S.L.R.I             1199 non-null   float64
#  6   A.T.T               1200 non-null   int64
#  7   L.M.I               1200 non-null   int64
#  8   L.M.C               1200 non-null   int64
#  9   S.R                 1200 non-null   int64
#  10  L.J.T.C             1199 non-null   float64
#  11  L.J.T.I             1200 non-null   int64
#  12  N.I.C               1200 non-null   int64
#  13  N.I.I               1200 non-null   int64
#  14  S.P.I               1198 non-null   float64
# ...

# %%
train_data.drop(['Interview Id','Candidate Id', 'Interviewer Id'],axis=1).describe()
# Out:
#            S.L.R.C      S.L.R.I        A.T.T        L.M.I        L.M.C  \
# count  5800.000000  5800.000000  5800.000000  5800.000000  5800.000000
# mean      0.748321     0.251679    69.927414    80.445172    80.084310
# std       0.144272     0.144272    29.464030    23.450059    23.540515
# min       0.500000     0.010000    20.000000    40.000000    40.000000
# 25%       0.620000     0.130000    44.000000    60.000000    59.000000
# 50%       0.750000     0.250000    70.000000    81.000000    81.000000
# 75%       0.870000     0.380000    96.000000   101.000000   101.000000
# max       0.990000     0.500000   120.000000   120.000000   120.000000
#
#                S.R      L.J.T.C      L.J.T.I        N.I.C        N.I.I  \
# count  5800.000000  5800.000000  5800.000000  5800.000000  5800.000000
# mean     45.077414   150.231207   301.063103    37.709828    37.378448
# std      14.729066    87.265858   172.861851    19.042870    19.138247
# ...

# %%
test_data.drop(['Interview Id','Candidate Id', 'Interviewer Id'],axis=1).describe()
# Out:
#            S.L.R.C      S.L.R.I        A.T.T        L.M.I        L.M.C  \
# count  1200.000000  1199.000000  1200.000000  1200.000000  1200.000000
# mean      0.737750     0.262369    70.198333    79.442500    81.379167
# std       0.144385     0.144387    29.114006    23.094469    23.088517
# min       0.500000     0.010000    20.000000    40.000000    40.000000
# 25%       0.610000     0.140000    44.750000    59.000000    62.000000
# 50%       0.740000     0.260000    71.000000    79.000000    81.000000
# 75%       0.860000     0.390000    96.000000    99.000000   102.000000
# max       0.990000     0.500000   120.000000   120.000000   120.000000
#
#                S.R      L.J.T.C      L.J.T.I        N.I.C        N.I.I  \
# count  1200.000000  1199.000000  1200.000000  1200.000000  1200.000000
# mean     45.013333   151.909091   304.809167    37.472500    37.708333
# std      14.597228    86.738285   175.226529    18.941134    19.190975
# ...

# %%
train_profile_counts = train_data['Profile'].value_counts()
test_profile_counts = test_data['Profile'].value_counts()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))


train_bars = ax1.bar(train_profile_counts.index, train_profile_counts, color='skyblue')
ax1.set_title('Distribution of Profiles in Train Data')
ax1.set_xlabel('Profile Types')
ax1.set_ylabel('Frequency')
ax1.tick_params(axis='x', rotation=45)


mean_train = train_profile_counts.mean()
median_train = train_profile_counts.median()
ax1.axhline(y=mean_train, color='r', linestyle='--', label='Mean')
ax1.axhline(y=median_train, color='g', linestyle='--', label='Median')


test_bars = ax2.bar(test_profile_counts.index, test_profile_counts, color='lightgreen')
ax2.set_title('Distribution of Profiles in Test Data')
ax2.set_xlabel('Profile Types')
ax2.set_ylabel('Frequency')
ax2.tick_params(axis='x', rotation=45)


mean_test = test_profile_counts.mean()
median_test = test_profile_counts.median()
ax2.axhline(y=mean_test, color='r', linestyle='--', label='Mean')
ax2.axhline(y=median_test, color='g', linestyle='--', label='Median')


ax1.legend()
ax2.legend()
plt.show()

# %%
train_pei_counts = train_data['P.E.I'].value_counts()
test_pei_counts = test_data['P.E.I'].value_counts()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))


ax1.pie(train_pei_counts, labels=train_pei_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
ax1.set_title('Distribution of Perceived Emotion - Interviewer in Train Data')


ax2.pie(test_pei_counts, labels=test_pei_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
ax2.set_title('Distribution of Perceived Emotion - Interviewer in Test Data')


plt.show()


train_pec_counts = train_data['P.E.C'].value_counts()
test_pec_counts = test_data['P.E.C'].value_counts()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))


ax1.pie(train_pec_counts, labels=train_pec_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
ax1.set_title('Distribution of Perceived Emotion - Candidate in Train Data')


ax2.pie(test_pec_counts, labels=test_pec_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
ax2.set_title('Distribution of Perceived Emotion - Candidate in Test Data')


plt.show()

# %%
plt.figure(figsize=(15, 6))


plt.subplot(1, 2, 1)
sns.countplot(data=train_data, x='Interviewer Intro', palette='pastel')
plt.title('Count of Interviewer Intro in Train Data')
plt.xlabel('Categories')
plt.ylabel('Count')


plt.subplot(1, 2, 2)
sns.countplot(data=test_data, x='Interviewer Intro', palette='pastel')
plt.title('Count of Interviewer Intro in Test Data')
plt.xlabel('Categories')
plt.ylabel('Count')


plt.tight_layout()
plt.show()

# %%
train_data.rename(columns={'Candidate into': 'Candidate Intro'}, inplace=True)
test_data.rename(columns={'Candidate into': 'Candidate Intro'}, inplace=True)

# %%
plt.figure(figsize=(15, 6))


plt.subplot(1, 2, 1)
sns.countplot(data=train_data, x='Candidate Intro', palette='pastel')
plt.title('Count of Candidate Intro in Train Data')
plt.xlabel('Categories')
plt.ylabel('Count')


plt.subplot(1, 2, 2)
sns.countplot(data=test_data, x='Candidate Intro', palette='pastel')
plt.title('Count of Candidate Intro in Test Data')
plt.xlabel('Categories')
plt.ylabel('Count')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))


plt.subplot(1, 2, 1)
sns.countplot(data=train_data, x='Opp to ask', palette='pastel')
plt.title('Count of Opp to ask in Train Data')
plt.xlabel('Categories')
plt.ylabel('Count')


plt.subplot(1, 2, 2)
sns.countplot(data=test_data, x='Opp to ask', palette='pastel')
plt.title('Count of Opp to ask in Test Data')
plt.xlabel('Categories')
plt.ylabel('Count')


plt.tight_layout()
plt.show()

# %%
status_counts = train_data['Status'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'], wedgeprops=dict(width=0.4))
my_circle = plt.Circle((0, 0), 0.6, color='white')
fig = plt.gcf()
fig.gca().add_artist(my_circle)
plt.title('Distribution of Status')
plt.show()

# %%
plt.figure(figsize=(15, 8))

ax = sns.countplot(data=train_data, x='Profile', hue='Status', palette='pastel')
plt.title('Status Distribution Across Different Profiles')
plt.xlabel('Profile')
plt.ylabel('Count')

total_counts = train_data['Profile'].value_counts()
for p in ax.patches:
    profile = train_data['Profile'][int(p.get_x()) // 3]
    total = total_counts[profile]
    height = p.get_height()
    ax.text(
        p.get_x() + p.get_width() / 2.,
        height + 3,
        '{:.1f}%'.format((height / total) * 100),
        ha="center"
    )


plt.xticks(rotation=45, ha='right')


plt.show()

# %%
pec_status_crosstab = pd.crosstab(train_data['P.E.C'], train_data['Status'])

pei_status_crosstab = pd.crosstab(train_data['P.E.I'], train_data['Status'])


plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.heatmap(pec_status_crosstab, annot=True, cmap="YlGnBu", fmt="d")
plt.title('Heatmap of P.E.C vs Status')


plt.subplot(1, 2, 2)
sns.heatmap(pei_status_crosstab, annot=True, cmap="YlGnBu", fmt="d")
plt.title('Heatmap of P.E.I vs Status')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(train_data.drop(['Interview Id','Candidate Id', 'Interviewer Id'],axis=1).corr(numeric_only=True), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
train_data.drop('S.L.R.I', axis=1, inplace=True)
test_data.drop('S.L.R.I', axis=1, inplace=True)

# %%
from scipy.stats import f_oneway, chi2_contingency

# %%
# Null : There is no significant difference between means of speaking times between different profiles

# %%
train_data.Profile.value_counts()
# Out:
# Developer          618
# Account Manager    598
# Sales              585
# QA Manual          585
# QA Automation      577
# Marketing          574
# Product Manager    571
# Program Manager    568
# Data Scientist     566
# HR                 558
# Name: Profile, dtype: int64

# %%
f_oneway(
    train_data[train_data.Profile=='Developer']['S.P.C'],
    train_data[train_data.Profile=='Account Manager']['S.P.C'],
    train_data[train_data.Profile=='Sales']['S.P.C'],
    train_data[train_data.Profile=='QA Manual']['S.P.C'],
    train_data[train_data.Profile=='QA Automation']['S.P.C'],
    train_data[train_data.Profile=='Marketing']['S.P.C'],
    train_data[train_data.Profile=='Product Manager']['S.P.C'],
    train_data[train_data.Profile=='Program Manager']['S.P.C'],
    train_data[train_data.Profile=='Data Scientist']['S.P.C'],
    train_data[train_data.Profile=='HR']['S.P.C']
)
# Out:
# F_onewayResult(statistic=1.9608703000754413, pvalue=0.039695817924487495)

# %%
train_data.dropna(subset=['Status'], inplace=True)

# %%
train_data.isnull().sum()
# Out:
# Interview Id          0
# Candidate Id          0
# Interviewer Id        0
# Profile               0
# S.L.R.C               0
# A.T.T                 0
# L.M.I                 0
# L.M.C                 0
# S.R                   0
# L.J.T.C               0
# L.J.T.I               0
# N.I.C                 0
# N.I.I                 0
# S.P.I                 0
# S.P.C                 0
# L.A.C                 0
# L.A.I                 0
# Q.A                   0
# P.E.I                 1
# P.E.C                 3
# COMPLIANCE Ratio      0
# Interview duration    0
# Interviewer Intro     1
# Candidate Intro       0
# Opp to ask            1
# Status                0
# dtype: int64

# %%
train_data['P.E.I'].fillna(train_data['P.E.I'].mode()[0], inplace=True)
train_data['P.E.C'].fillna(train_data['P.E.C'].mode()[0], inplace=True)
train_data['Interviewer Intro'].fillna(train_data['Interviewer Intro'].mode()[0], inplace=True)
train_data['Opp to ask'].fillna(train_data['Opp to ask'].mode()[0], inplace=True)

# %%
test_data.isnull().sum()
# Out:
# Interview Id          0
# Candidate Id          0
# Interviewer Id        0
# Profile               0
# S.L.R.C               0
# A.T.T                 0
# L.M.I                 0
# L.M.C                 0
# S.R                   0
# L.J.T.C               1
# L.J.T.I               0
# N.I.C                 0
# N.I.I                 0
# S.P.I                 2
# S.P.C                 0
# L.A.C                 0
# L.A.I                 1
# Q.A                   1
# P.E.I                 2
# P.E.C                 2
# COMPLIANCE Ratio      1
# Interview duration    0
# Interviewer Intro     2
# Candidate Intro       0
# Opp to ask            0
# dtype: int64

# %%
test_data['L.J.T.C'].fillna(test_data['L.J.T.C'].mode()[0], inplace=True)
test_data['S.P.I'].fillna(test_data['S.P.I'].mode()[0], inplace=True)
test_data['L.A.I'].fillna(test_data['L.A.I'].mode()[0], inplace=True)
test_data['Q.A'].fillna(test_data['Q.A'].mode()[0], inplace=True)
test_data['P.E.I'].fillna(test_data['P.E.I'].mode()[0], inplace=True)
test_data['P.E.C'].fillna(test_data['P.E.C'].mode()[0], inplace=True)
test_data['COMPLIANCE Ratio'].fillna(test_data['COMPLIANCE Ratio'].mode()[0], inplace=True)
test_data['Interviewer Intro'].fillna(test_data['Interviewer Intro'].mode()[0], inplace=True)

# %%
train_data
# Out:
#       Interview Id  Candidate Id  Interviewer Id          Profile  S.L.R.C  \
# 0     6.913030e+11  2.655774e+09             194        Developer     0.98
# 1     9.214326e+11  7.123846e+08             234            Sales     0.67
# 2     4.718839e+10  8.445533e+08             267  Program Manager     0.81
# 3     9.943741e+11  6.511106e+09             199        Marketing     0.69
# 4     3.509007e+11  3.487001e+09             221    QA Automation     0.57
# ...            ...           ...             ...              ...      ...
# 5794  9.622751e+11  4.312842e+09             242   Data Scientist     0.71
# 5796  2.129354e+11  6.833534e+09             230        QA Manual     0.69
# 5797  8.850640e+11  4.657574e+09             253  Product Manager     0.64
# 5798  6.047461e+11  8.118565e+08             257            Sales     0.94
# 5799  8.630407e+11  3.494633e+09             242        Developer     0.83
#
# ...

# %%
#test_data['Status'] = 'test'

# %%
#concat_df = pd.concat([train_data,test_data])

# %%
#oncat_df

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
nominal_cols = ['Profile', 'Interviewer Intro', 'Candidate Intro', 'Opp to ask']


one_hot_encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
train_data_encoded = pd.get_dummies(train_data, columns=nominal_cols)
test_data_encoded = pd.get_dummies(test_data, columns=nominal_cols)

# %%
ordinal_cols = ['P.E.I', 'P.E.C']


label_encoder = LabelEncoder()
for col in ordinal_cols:
    train_data[col + '_encoded'] = label_encoder.fit_transform(train_data[col])
    test_data[col + '_encoded'] = label_encoder.transform(test_data[col])

# %%
train_data_encoded = pd.get_dummies(train_data, columns=nominal_cols)
test_data_encoded = pd.get_dummies(test_data, columns=nominal_cols)

train_data = pd.concat([train_data, train_data_encoded], axis=1)
test_data = pd.concat([test_data, test_data_encoded], axis=1)

train_data.drop(columns=nominal_cols, inplace=True)
test_data.drop(columns=nominal_cols, inplace=True)

# %%
train_data_encoded.drop(columns=ordinal_cols, inplace=True)
test_data_encoded.drop(columns=ordinal_cols, inplace=True)

# %%
train_data_encoded
# Out:
#       Interview Id  Candidate Id  Interviewer Id  S.L.R.C  A.T.T  L.M.I  \
# 0     6.913030e+11  2.655774e+09             194     0.98     53     88
# 1     9.214326e+11  7.123846e+08             234     0.67     51     53
# 2     4.718839e+10  8.445533e+08             267     0.81     60     77
# 3     9.943741e+11  6.511106e+09             199     0.69     93     42
# 4     3.509007e+11  3.487001e+09             221     0.57     44     44
# ...            ...           ...             ...      ...    ...    ...
# 5794  9.622751e+11  4.312842e+09             242     0.71     32    101
# 5796  2.129354e+11  6.833534e+09             230     0.69     34     81
# 5797  8.850640e+11  4.657574e+09             253     0.64     58     58
# 5798  6.047461e+11  8.118565e+08             257     0.94    104     55
# 5799  8.630407e+11  3.494633e+09             242     0.83    102     87
#
#       L.M.C  S.R  L.J.T.C  L.J.T.I  ...  Profile_Program Manager  \
# ...

# %%
test_data_encoded.columns
# Out:
# Index(['Interview Id', 'Candidate Id', 'Interviewer Id', 'S.L.R.C', 'A.T.T',
#        'L.M.I', 'L.M.C', 'S.R', 'L.J.T.C', 'L.J.T.I', 'N.I.C', 'N.I.I',
#        'S.P.I', 'S.P.C', 'L.A.C', 'L.A.I', 'Q.A', 'COMPLIANCE Ratio',
#        'Interview duration', 'P.E.I_encoded', 'P.E.C_encoded',
#        'Profile_Account Manager', 'Profile_Data Scientist',
#        'Profile_Developer', 'Profile_HR', 'Profile_Marketing',
#        'Profile_Product Manager', 'Profile_Program Manager',
#        'Profile_QA Automation', 'Profile_QA Manual', 'Profile_Sales',
#        'Interviewer Intro_No', 'Interviewer Intro_Yes', 'Candidate Intro_No',
#        'Candidate Intro_Yes', 'Opp to ask_No', 'Opp to ask_Yes'],
#       dtype='object')

# %%
train_data_encoded.drop(['Interview Id', 'Candidate Id', 'Interviewer Id'], axis=1, inplace=True)
test_data_encoded.drop(['Interview Id', 'Candidate Id', 'Interviewer Id'], axis=1, inplace=True)

# %%
numerical_features = ['S.L.R.C',  'A.T.T', 'L.M.I', 'L.M.C', 'S.R', 'L.J.T.C', 'L.J.T.I', 'N.I.C', 'N.I.I', 'S.P.I', 'S.P.C', 'L.A.C', 'L.A.I', 'Q.A', 'COMPLIANCE Ratio', 'Interview duration']

for feature in numerical_features:
    sns.boxplot(x=train_data_encoded[feature])
    plt.title(f'Boxplot of {feature}')
    plt.show()

# %%
numerical_features = ['S.L.R.C',  'A.T.T', 'L.M.I', 'L.M.C', 'S.R', 'L.J.T.C', 'L.J.T.I', 'N.I.C', 'N.I.I', 'S.P.I', 'S.P.C', 'L.A.C', 'L.A.I', 'Q.A', 'COMPLIANCE Ratio', 'Interview duration']

for feature in numerical_features:
    sns.boxplot(x=test_data_encoded[feature])
    plt.title(f'Boxplot of {feature}')
    plt.show()

# %%
from sklearn.model_selection import train_test_split


X = train_data_encoded.drop(columns=['Status'])
y = train_data_encoded['Status']


X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.8, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(C = 10,penalty = 'l1', solver='liblinear',max_iter=10000000)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=10, max_iter=10000000, penalty='l1', solver='liblinear')

# %%
lr.score(X_train,y_train)
# Out:
# 1.0

# %%
lr_val_pred = lr.predict(X_val)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
print(accuracy_score(y_val,lr_val_pred))
# Out:
# 0.9775717058442959

# %%
print(classification_report(y_val,lr_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Consider       0.99      1.00      0.99      1833
# May Consider       0.98      0.95      0.97      1528
# Not Consider       0.97      0.98      0.97      1276
#
#     accuracy                           0.98      4637
#    macro avg       0.98      0.98      0.98      4637
# weighted avg       0.98      0.98      0.98      4637

# %%
from sklearn.model_selection import cross_val_score

# %%
np.mean(cross_val_score(lr,X_train,y_train,cv=5))
# Out:
# 0.9793028810270188

# %%
lr_pred = lr.predict(test_data_encoded)

# %%
submission = pd.read_csv('sample_IA_-_sample.csv')

# %%
submission.Status = lr_pred

# %%
submission.to_csv('lr_pred5.csv',index=False)

# %%
pd.DataFrame(lr_pred).value_counts()
# Out:
# Consider        495
# May Consider    388
# Not Consider    317
# dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion='entropy',max_depth=7,min_samples_split=10,min_samples_leaf=15,max_features=30)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features=30,
#                        min_samples_leaf=15, min_samples_split=10)

# %%
dt.score(X_train,y_train)
# Out:
# 0.9191113028472822

# %%
print(accuracy_score(y_val,dt.predict(X_val)))
# Out:
# 0.8698275862068966

# %%
np.mean(cross_val_score(dt, X_train,y_train))
# Out:
# 0.8679879012758992

# %%
dt_pred = dt.predict(test_data_encoded)

# %%
submission.Status = dt_pred

# %%
submission.to_csv('dt_pred2.csv',index=False)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
rf = RandomForestClassifier(n_estimators=390,criterion='entropy',max_depth=7,min_samples_split=10,min_samples_leaf=15,max_features=30,
                            )

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=7, max_features=30,
#                        min_samples_leaf=15, min_samples_split=10,
#                        n_estimators=390)

# %%
rf.score(X_train,y_train)
# Out:
# 0.9503882657463331

# %%
print(accuracy_score(y_val,rf.predict(X_val)))
# Out:
# 0.9112068965517242

# %%
np.mean(cross_val_score(rf,X_train,y_train))
# Out:
# 0.9063804262917085

# %%
rf_pred = rf.predict(test_data_encoded)



submission.Status = rf_pred

submission.to_csv('rf_pred2.csv',index=False)

# %%
gb=GradientBoostingClassifier(n_estimators=390,max_depth=7,min_samples_split=10,min_samples_leaf=15,max_features=30,
                              learning_rate=1.19)

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=1.19, max_depth=7, max_features=30,
#                            min_samples_leaf=15, min_samples_split=10,
#                            n_estimators=390)

# %%
gb.score(X_train,y_train)
# Out:
# 1.0

# %%
print(accuracy_score(y_val,gb.predict(X_val)))
# Out:
# 0.9310047434238896

# %%
np.mean(cross_val_score(gb,X_train,y_train))
# Out:
# 0.9209100305962128

# %%
gb_pred = gb.predict(test_data_encoded)

# %%
submission.Status = gb_pred

# %%
pd.DataFrame(gb_pred).value_counts()
# Out:
# Consider        476
# May Consider    412
# Not Consider    312
# dtype: int64

# %%
submission.to_csv('gb.csv',index=False)

# %%
submission
# Out:
#       Interview Id        Status
# 0     702127796635      Consider
# 1     613490569071  May Consider
# 2     759998772623  May Consider
# 3     391760082113  Not Consider
# 4     941599210196  Not Consider
# ...            ...           ...
# 1195  256033687434  Not Consider
# 1196  627337316047      Consider
# 1197   75547031851  Not Consider
# 1198  173914777164  May Consider
# 1199  480519602140  May Consider
#
# [1200 rows x 2 columns]

# %%
from sklearn.svm import SVC

# %%
sv = SVC(C= 90,kernel='linear')

# %%
sv.fit(X_train,y_train)
# Out:
# SVC(C=90, kernel='linear')

# %%
sv.score(X_train,y_train)
# Out:
# 1.0

# %%
print(accuracy_score(y_val,sv.predict(X_val)))
# Out:
# 0.9982758620689656

# %%
np.mean(cross_val_score(sv,X_train,y_train))
# Out:
# 0.9967646840010416

# %%
sv_pred = sv.predict(test_data_encoded)



submission.Status = sv_pred

submission.to_csv('sv.csv',index=False)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=9,metric='euclidean')

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=9)

# %%
knn.score(X_train,y_train)
# Out:
# 0.8990509059534081

# %%
print(accuracy_score(y_val,knn.predict(X_val)))
# Out:
# 0.8560344827586207

# %%
np.mean(cross_val_score(knn,X_train,y_train))
# Out:
# 0.8548278651936169

# %%
X_train
# Out:
#       S.L.R.C  A.T.T  L.M.I  L.M.C  S.R  L.J.T.C  L.J.T.I  N.I.C  N.I.I  \
# 5687     0.62    100     64     62   55      218       49     51     25
# 203      0.67     90     59     75   41      173      193     55     41
# 339      0.75     50    104     81   46      279      156     45     26
# 838      0.88     27     72     84   60        0      291      8     38
# 4207     0.67     26     66    108   42       73      114     22     53
# ...       ...    ...    ...    ...  ...      ...      ...    ...    ...
# 3773     0.50    115     86    105   62       11       78     70     47
# 5194     0.68     53     87     72   36      213      399     62     68
# 5229     0.65     85    103    108   54      227      441     16     59
# 5393     0.94     35     55     93   60      124      507     31     24
# 861      0.50     62     43     44   42      294       27     48      7
#
#       S.P.I  ...  Profile_Program Manager  Profile_QA Automation  \
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam


model = Sequential()

# Add the input layer
model.add(Dense(64, input_dim=34, activation='relu'))

# Add hidden layers
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

# Add the output layer with softmax activation for multi-class classification
model.add(Dense(3, activation='softmax'))

# Compile the model with the Adam optimizer and 'accuracy' as the metric
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print the summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 64)                2240
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 3)                 195
#
# ...
# Total params: 10755 (42.01 KB)
# Trainable params: 10755 (42.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
pd.DataFrame(y_train).value_counts()
# Out:
# Status
# Consider        1842
# May Consider    1501
# Not Consider    1293
# dtype: int64

# %%
y_train1 = pd.DataFrame(y_train).replace({'Not Consider':0,'May Consider':1,'Consider':2})

# %%
model.fit(X_train, pd.DataFrame(y_train1).Status, epochs=100, batch_size=32, verbose=0)

# %%
y_val1 = pd.DataFrame(y_val).replace({'Not Consider':0,'May Consider':1,'Consider':2})

# %%
(model.evaluate(X_train,y_train1))[1]
# Out:
# 19/19 [==============================] - 0s 2ms/step - loss: 9.1517e-07 - accuracy: 1.0000
# 1.0

# %%
model.evaluate(X_val,y_val1)[1]
# Out:
# 164/164 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 0.9873
# 0.9873490333557129

# %%
mlp_pred = model.predict(test_data_encoded)

predicted_labels = np.argmax(mlp_pred, axis=1)

predicted_labels = pd.DataFrame(predicted_labels).replace({0:'Not Consider', 1:'May Consider', 2:'Consider'})

print(predicted_labels)
# Out:
# 38/38 [==============================] - 0s 2ms/step
#                  0
# 0         Consider
# 1     May Consider
# 2     May Consider
# 3     Not Consider
# 4     Not Consider
# ...            ...
# 1195  Not Consider
# 1196      Consider
# 1197  Not Consider
# 1198  May Consider
# 1199  May Consider
#
# [1200 rows x 1 columns]

# %%
pd.DataFrame(lr_pred).value_counts()
# Out:
# Consider        488
# May Consider    401
# Not Consider    311
# dtype: int64

# %%
pd.DataFrame(sv_pred).value_counts()
# Out:
# Consider        487
# May Consider    405
# Not Consider    308
# dtype: int64

# %%
pd.DataFrame(predicted_labels).value_counts()
# Out:
# Consider        491
# May Consider    388
# Not Consider    321
# dtype: int64

# %%
submission1=pd.read_csv('sample_IA_-_sample.csv')

# %%
submission1.Status.value_counts()
# Out:
# Consider        643
# May Consider    463
# Not Consider     94
# Name: Status, dtype: int64

# %%
submission1.Status= predicted_labels

# %%
submission1.to_csv('mlp1.csv',index=False)

# %%
submission1.Status.value_counts()
# Out:
# Consider        491
# May Consider    388
# Not Consider    321
# Name: Status, dtype: int64
